# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as sts

alpha = 0.5
beta = 0.5
# %matplotlib inline

# %%
beta_rv = sts.beta(alpha, beta)
sample = beta_rv.rvs(1000)

# %%
x = np.linspace(0,1,100)
pdf = beta_rv.pdf(x)
plt.hist(sample, normed=True)
plt.plot(x, pdf, label='theoretical pdf', alpha=0.5)
plt.legend()
plt.ylabel('$f(x)$')
plt.xlabel('$x$')
# Out:
# Text(0.5,0,'$x$')

# %%
def get_distribution(n):
    def get_value(): 
        return sum(beta_rv.rvs(n))/n
    return np.array([get_value() for _index in range(1000)])

# %%
plt.hist(get_distribution(2), normed=True)
# Out:
# (array([ 0.85773087,  0.79718516,  0.99900419,  1.03936799,  1.38246034,
#          1.73564363,  0.94854943,  0.89809467,  0.79718516,  0.63572994]),
#  array([ 0.00470245,  0.10380113,  0.20289982,  0.3019985 ,  0.40109719,
#          0.50019587,  0.59929455,  0.69839324,  0.79749192,  0.89659061,
#          0.99568929]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(get_distribution(5), normed=True)
# Out:
# (array([ 0.06633676,  0.2542909 ,  0.76287271,  1.52574543,  2.41023553,
#          2.43234778,  1.9790466 ,  1.08350037,  0.38696442,  0.15478577]),
#  array([ 0.02374769,  0.11419528,  0.20464288,  0.29509047,  0.38553806,
#          0.47598565,  0.56643325,  0.65688084,  0.74732843,  0.83777602,
#          0.92822361]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(get_distribution(10), normed=True)
# Out:
# (array([ 0.12237146,  0.67984145,  1.65881314,  3.01849603,  3.30402944,
#          2.84173726,  1.59082899,  0.29913024,  0.05438732,  0.02719366]),
#  array([ 0.17704249,  0.25058905,  0.32413561,  0.39768217,  0.47122873,
#          0.54477529,  0.61832185,  0.69186841,  0.76541497,  0.83896153,
#          0.91250809]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(get_distribution(50), normed=True)
# Out:
# (array([ 0.38348243,  1.11558525,  3.52106596,  6.10085685,  7.73937269,
#          7.59992454,  4.91554752,  2.26603255,  0.94127506,  0.27889631]),
#  array([ 0.35937326,  0.38805775,  0.41674225,  0.44542674,  0.47411124,
#          0.50279574,  0.53148023,  0.56016473,  0.58884922,  0.61753372,
#          0.64621821]),
#  <a list of 10 Patch objects>)
